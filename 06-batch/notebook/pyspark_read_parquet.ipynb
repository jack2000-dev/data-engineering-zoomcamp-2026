# %% [markdown]
# After using `download_data.sh` to download the data, we then run the script `green_taxi_data.py` to convert the CSV files into Parquet files. The script reads the CSV files, applies a schema, and writes the data to Parquet format with a specified number of partitions.

# %%
  # Run the script
  # !uv run spark-submit green_taxi_data.py

# %%
# !uv run spark-submit yellow_taxi_data.py

# %% [markdown]
# # Reading Parquet Files with PySpark

# %%
  # !uv run pyspark

# %%
df_green = spark.read.parquet('data/pq/green/*/*')

df_green \
    .select('lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID', 'trip_distance') \
    .show()
